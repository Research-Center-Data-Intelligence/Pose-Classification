# %%
import os
import joblib
import numpy as np

def mirror_keypoints_and_save(dataset_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, dirs, files in os.walk(dataset_dir):
        for file in files:
            if file.endswith('.pth'):
                video_path = os.path.join(root, file)
                print(f"Processing file: {video_path}")

                tracking_results = joblib.load(video_path)
                mirrored_tracking_results = []

                for result in tracking_results:
                    keypoints = result['keypoints']
                    mirrored_keypoints = keypoints.copy()

                    mirrored_keypoints[:, :, 0] = -mirrored_keypoints[:, :, 0]

                    mirrored_result = {
                        'bbox': result['bbox'], 
                        'keypoints': mirrored_keypoints,
                    }
                    mirrored_tracking_results.append(mirrored_result)

                base_name = os.path.splitext(file)[0]
                output_file_name = f"{base_name}_MIRRORED.pth"

                relative_path = os.path.relpath(root, dataset_dir)
                output_path = os.path.join(output_dir, relative_path, output_file_name)

                output_folder = os.path.dirname(output_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                joblib.dump(mirrored_tracking_results, output_path)
                print(f"Saved mirrored file: {output_path}")

dataset_dir = "dataset/keypoints/"
output_dir = "dataset/mirrored_keypoints/" 
mirror_keypoints_and_save(dataset_dir, output_dir)
# Out:
# Processing file: dataset/keypoints/ARM_RAISE\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\1_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\2_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\3_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\4_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\5_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\6_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\7_MIRRORED.pth
# Processing file: dataset/keypoints/ARM_RAISE\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/ARM_RAISE\8_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\1_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\2_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\3_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\4_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\5_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\6_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\7_MIRRORED.pth
# Processing file: dataset/keypoints/CHAIR_RAISE_AND_STEP\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/CHAIR_RAISE_AND_STEP\8_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\1_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\2_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\3_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\4_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\5_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\6_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\7_MIRRORED.pth
# Processing file: dataset/keypoints/HEAD_LIFT\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/HEAD_LIFT\8_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\1_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\2_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\3_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\4_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\5_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\6_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\7_MIRRORED.pth
# Processing file: dataset/keypoints/LEG_RAISE\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/LEG_RAISE\8_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\1_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\2_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\3_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\4_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\5_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\6_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\7_MIRRORED.pth
# Processing file: dataset/keypoints/PICK_UP\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/PICK_UP\8_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\1_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\2_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\3_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\4_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\5_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\6_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\7_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_ALL_FOURS_RISE\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_ALL_FOURS_RISE\8_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\1_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\2_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\3_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\4_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\5_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\6_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\7_MIRRORED.pth
# Processing file: dataset/keypoints/SIT_UP\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/SIT_UP\8_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\1.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\1_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\2.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\2_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\3.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\3_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\4.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\4_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\5.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\5_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\6.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\6_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\7.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\7_MIRRORED.pth
# Processing file: dataset/keypoints/SUPINE_TO_PRONE\8.pth
# Saved mirrored file: dataset/mirrored_keypoints/SUPINE_TO_PRONE\8_MIRRORED.pth
